# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
data = pd.read_csv('CAX_Startup_Data.csv')

# %%
data = data[['Dependent-Company Status','Employee Count','Number of Investors in Seed','Number of Investors in Angel and or VC','Number of Co-founders','Number of of advisors','Team size Senior leadership','Number of of repeat investors','Worked in top companies','Have been part of startups in the past?','Have been part of successful startups in the past?','Was he or she partner in Big 5 consulting?','Consulting experience?','Local or global player','B2C or B2B venture?','Average Years of experience for founder and co founder','Breadth of experience across verticals','Years of education','Relevance of education to venture','Relevance of experience to venture','Experience in selling and building products','Dificulty of Obtaining Work force','Pricing Strategy','Time to market service or product','Barriers of entry for the competitors','Company awards','Disruptiveness of technology','Gartner hype cycle stage']]
data.head()
# Out:
#   Dependent-Company Status  Employee Count Number of Investors in Seed  \
# 0                  Success             3.0                           2
# 1                  Success             NaN                           5
# 2                  Success            14.0                          15
# 3                  Success            45.0                           6
# 4                  Success            39.0                           7
#
#   Number of Investors in Angel and or VC  Number of Co-founders  \
# 0                                      0                      1
# 1                                      0                      2
# 2                                      0                      3
# 3                                      0                      2
# 4                                      0                      1
#
#    Number of of advisors  Team size Senior leadership  \
# 0                      2                            2
# ...

# %%
data = data.replace('No Info',np.nan)

# %%
data = data.dropna()

# %%
data['Employee Count'] = data['Employee Count'].astype(int)
data['Number of Investors in Seed'] = data['Number of Investors in Seed'].astype(int)
data['Number of Investors in Angel and or VC'] = data['Number of Investors in Angel and or VC'].astype(int)
data['Number of of repeat investors'] = data['Number of of repeat investors'].astype(int)
data['Number of Investors in Seed'] = data['Number of Investors in Seed'].astype(int)
data['Local or global player'] = data['Local or global player'].str.lower()
data
# Out:
#     Dependent-Company Status  Employee Count  Number of Investors in Seed  \
# 2                    Success              14                           15
# 3                    Success              45                            6
# 5                    Success              14                            2
# 6                    Success               7                            7
# 7                    Success              29                            0
# ..                       ...             ...                          ...
# 386                   Failed             139                            0
# 387                   Failed              26                            0
# 388                   Failed              39                            0
# 389                   Failed              63                            0
# 391                   Failed              18                            0
#
#      Number of Investors in Angel and or VC  Number of Co-founders  \
# ...

# %%
cat_vars=[
       'Worked in top companies', 'Have been part of startups in the past?',
       'Have been part of successful startups in the past?',
       'Was he or she partner in Big 5 consulting?', 'Consulting experience?',
       'Local or global player', 'B2C or B2B venture?',
       'Average Years of experience for founder and co founder',
       'Breadth of experience across verticals', 'Years of education',
       'Relevance of education to venture',
       'Relevance of experience to venture',
       'Experience in selling and building products',
       'Dificulty of Obtaining Work force', 'Pricing Strategy',
       'Time to market service or product',
       'Barriers of entry for the competitors', 'Company awards',
       'Disruptiveness of technology', 'Gartner hype cycle stage']
for var in cat_vars:
    cat_list='var'+'_'+var
    cat_list = pd.get_dummies(data[var], prefix=var)
    data1=data.join(cat_list)
    data=data1
    
    
cat_vars=['job','marital','education','default','housing','loan','contact','month','day_of_week','poutcome']
data_vars=data.columns.values.tolist()
to_keep=[i for i in data_vars if i not in cat_vars]

# %%
data_final=data[to_keep]

# %%
list1 = data['Dependent-Company Status'].to_list()
new_list = []

for x in list1:
    if x == 'Success':
        new_list.append(1)
    else:
        new_list.append(0)
        
len(list1)
# Out:
# 192

# %%
data_final['status'] = new_list
data_final
# Out:
#     Dependent-Company Status  Employee Count  Number of Investors in Seed  \
# 2                    Success              14                           15
# 3                    Success              45                            6
# 5                    Success              14                            2
# 6                    Success               7                            7
# 7                    Success              29                            0
# ..                       ...             ...                          ...
# 386                   Failed             139                            0
# 387                   Failed              26                            0
# 388                   Failed              39                            0
# 389                   Failed              63                            0
# 391                   Failed              18                            0
#
#      Number of Investors in Angel and or VC  Number of Co-founders  \
# ...

# %%
data_final.to_csv('Clean.csv',index=False)

# %%
data_final = data_final.drop(['Dependent-Company Status',
       'Worked in top companies', 'Have been part of startups in the past?',
       'Have been part of successful startups in the past?',
       'Was he or she partner in Big 5 consulting?', 'Consulting experience?',
       'Local or global player', 'B2C or B2B venture?',
       'Average Years of experience for founder and co founder',
       'Breadth of experience across verticals', 'Years of education',
       'Relevance of education to venture',
       'Relevance of experience to venture',
       'Experience in selling and building products',
       'Dificulty of Obtaining Work force', 'Pricing Strategy',
       'Time to market service or product',
       'Barriers of entry for the competitors', 'Company awards',
       'Disruptiveness of technology', 'Gartner hype cycle stage'],axis='columns')

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

X = data_final.drop(['status'], axis='columns')
y = data_final['status']
X
# Out:
#      Employee Count  Number of Investors in Seed  \
# 2                14                           15
# 3                45                            6
# 5                14                            2
# 6                 7                            7
# 7                29                            0
# ..              ...                          ...
# 386             139                            0
# 387              26                            0
# 388              39                            0
# 389              63                            0
# 391              18                            0
#
#      Number of Investors in Angel and or VC  Number of Co-founders  \
# 2                                         0                      3
# 3                                         0                      2
# 5                                         0                      4
# 6                                         0                      2
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(max_iter=10000)
logreg.fit(X,y)
y_pred=logreg.predict(X_test)
y_pred=np.round(y_pred)

# %%
from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[ 3,  3],
#        [ 1, 41]])

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
class_names=[0,1] # name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("Precision:",metrics.precision_score(y_test, y_pred))
print("Recall:",metrics.recall_score(y_test, y_pred))
# Out:
# Accuracy: 0.9166666666666666
# Precision: 0.9318181818181818
# Recall: 0.9761904761904762

# %%
logreg.score(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-78c95c8a67f0> in <module>
# ----> 1 logreg.score(X_train,y_train)
#
# NameError: name 'logreg' is not defined

# %% [markdown]
# ## Predicting Startup Success

# %% [markdown]
# Please insert the following details abot the startup you want to evaluate. At the end, insert the email you wish the results to be sent.

# %%
employee = input('Input the number of employees of the startup: ')

# %%
seed = input('Input the number of Investors in Seed: ')

# %%
vc = input('Input the number of Investors in Angel and Seed: ')

# %%
advisors = input('Input the number of advisors: ')

# %%
co_founders = input('Input the number of co_founders: ')

# %%
senior = input('Input the number of elements of senior leadership team: ')

# %%
repeat = input('Input the number of repeat investors: ')

# %%
top_comp = input('Did the founder work in top companies before? (Yes or No) ')

# %%
past_su = input('Was the founder a part of startups in the past? (Yes or No) ')

# %%
past_ssu = input('Was the founder a part of successful startups in the past? (Yes or No) ')

# %%
big5 = input('Was the founder a partner in a Big5 before? (Yes or No) ')

# %%
consulting = input('Does the founder have experience in consulting? (Yes or No) ')

# %%
where = input('Is the startup global or local? ')

# %%
market = input('Is the company B2B or B2C? ')

# %%
experience = input('What is the level of experience for founder and co founder? (Low, Medium or High) ')

# %%
experience1 = input('What is the breadth of experience of founder across verticals? (Low, Medium or High)')

# %%
education = input('What is the highest education elevel of founder? (High-school, Bachelor or Masters) ')

# %%
ed_relevance = input("Is the founder's education relevant to the startup model? (Yes or No) ")

# %%
ex_relevance = input("Is the founder's past experience relevant to the startup model? (Yes or No) ")

# %%
selling = input("What is the level of experience of the founder in selling and building products? (None, Low, Medium, High) ")

# %%
workforce = input("What is the startup's difficulty level of Obtaining Work force? (Low,Medium,High) ")

# %%
pricing = input('Does the startup has a pricing strategy? (Yes or No) ')

# %%
time = input('What is the level of time to market of service or product sold? (Low, Medium, High) ')

# %%
barriers = input('Are there barriers of entry for competitors? (Yes or No) ')

# %%
awards = input('Was the startup given any awards? (Yes or No) ')

# %%
disruptive = input('What is the level of the disruptiveness of technology? (Low, Medium, High) ')

# %%
gartner = input('What is the stage of product/service according to the Gartner hype cycle? (Trigger,Peak, Plateau, Slope, Trough)')

# %%
email_receiver = input('Input your email, so we can send you the report. Thanks!')

# %%
if top_comp == 'Yes':
    top_comp_yes = 1
    top_comp_no = 0
elif top_comp == 'No':
    top_comp_yes = 0
    top_comp_no = 1
else:
    print('Error in inputed variable.')
    
if past_su == 'Yes':
    past_su_yes = 1
    past_su_no = 0
elif past_su == 'No':
    past_su_yes = 0
    past_su_no = 1
else:
    print('Error in inputed variable.')
    
if past_ssu == 'Yes':
    past_ssu_yes = 1
    past_ssu_no = 0
elif past_ssu == 'No':
    past_ssu_yes = 0
    past_ssu_no = 1
else:
    print('Error in inputed variable.')

if big5 == 'Yes':
    big5_yes = 1
    big5_no = 0
elif big5 == 'No':
    big5_yes = 0
    big5_no = 1
else:
    print('Error in inputed variable.')
    
if consulting == 'Yes':
    consulting_yes = 1
    consulting_no = 0
elif consulting == 'No':
    consulting_yes = 0
    consulting_no = 1
else:
    print('Error in inputed variable.')
    
if where == 'local':
    where_local = 1
    where_global = 0
elif consulting == 'global':
    where_local = 0
    where_global = 1
else:
    print('Error in inputed variable.')

if market == 'B2B':
    market_B2B = 1
    market_B2C = 0
elif market == 'B2C':
    market_B2B = 0
    market_B2C = 1
else:
    print('Error in inputed variable.')

if experience == 'Low':
    experience_low = 1
    experience_medium = 0
    experience_high = 0
elif experience == 'Medium':
    experience_low = 0
    experience_medium = 1
    experience_high = 0
elif experience == 'High':
    experience_low = 0
    experience_medium = 0
    experience_high = 1
else:
    print('Error in inputed variable.')

if experience1 == 'Low':
    experience1_low = 1
    experience1_medium = 0
    experience1_high = 0
elif experience1 == 'Medium':
    experience1_low = 0
    experience1_medium = 1
    experience1_high = 0
elif experience1 == 'High':
    experience1_low = 0
    experience1_medium = 0
    experience1_high = 1
else:
    print('Error in inputed variable.')

if education == 'High-school':
    education_18 = 1
    education_21 = 0
    education_25 = 0
elif education == 'Bachelor':
    education_18 = 0
    education_21 = 1
    education_25 = 0
elif education == 'Masters':
    education_18 = 0
    education_21 = 0
    education_25 = 1
else:
    print('Error in inputed variable.')
    
if ed_relevance == 'Yes':
    ed_relevance_yes = 1
    ed_relevance_no = 0
elif ed_relevance == 'No':
    ed_relevance_yes = 0
    ed_relevance_no = 1
else:
    print('Error in inputed variable.')
    
if ex_relevance == 'Yes':
    ex_relevance_yes = 1
    ex_relevance_no = 0
elif ex_relevance == 'No':
    ex_relevance_yes = 0
    ex_relevance_no = 1
else:
    print('Error in inputed variable.')
    
if selling == 'None':
    selling_none = 1
    selling_low = 0
    selling_medium = 0
    selling_high = 0
elif selling == 'Low':
    selling_none = 0
    selling_low = 1
    selling_medium = 0
    selling_high = 0
elif selling == 'Medium':
    selling_none = 0
    selling_low = 0
    selling_medium = 1
    selling_high = 0
elif selling == 'High':
    selling_none = 0
    selling_low = 0
    selling_medium = 0
    selling_high = 1
else:
    print('Error in inputed variable.')
    
if workforce == 'Low':
    worforce_low = 1
    workforce_medium = 0
    workforce_high = 0
elif workforce == 'Medium':
    workforce_low = 0
    workforce_medium = 1
    workforce_high = 0
elif workforce == 'High':
    workforce_low = 0
    workforce_medium = 0
    workforce_high = 1
else:
    print('Error in inputed variable.')
    
if pricing == 'Yes':
    pricing_yes = 1
    pricing_no = 0
elif pricing == 'No':
    pricing_yes = 0
    pricing_no = 1
else:
    print('Error in inputed variable.')
    
if time == 'Low':
    time_low = 1
    time_medium = 0
    time_high = 0
elif time == 'Medium':
    time_low = 0
    time_medium = 1
    time_high = 0
elif time == 'High':
    time_low = 0
    time_medium = 0
    time_high = 1
else:
    print('Error in inputed variable.')

if barriers == 'Yes':
    barriers_yes = 1
    barriers_no = 0
elif barriers == 'No':
    barriers_yes = 0
    barriers_no = 1
else:
    print('Error in inputed variable.')
    
if awards == 'Yes':
    awards_yes = 1
    awards_no = 0
elif awards == 'No':
    awards_yes = 0
    awards_no = 1
else:
    print('Error in inputed variable.')

if disruptive == 'Low':
    disruptive_low = 1
    disruptive_medium = 0
    disruptive_high = 0
elif disruptive == 'Medium':
    disruptive_low = 0
    disruptive_medium = 1
    disruptive_high = 0
elif disruptive == 'High':
    disruptive_low = 0
    disruptive_medium = 0
    disruptive_high = 1
else:
    print('Error in inputed variable.')
                
if gartner == 'Trigger':
    gartner_tri = 1
    gartner_peak = 0
    gartner_pla = 0
    gartner_slo = 0
    gartner_tro = 0
elif gartner == 'Peak':
    gartner_tri = 0
    gartner_peak = 1
    gartner_pla = 0
    gartner_slo = 0
    gartner_tro = 0
elif gartner == 'Plateau':
    gartner_tri = 0
    gartner_peak = 0
    gartner_pla = 1
    gartner_slo = 0
    gartner_tro = 0
elif gartner == 'Slope':
    gartner_tri = 0
    gartner_peak = 0
    gartner_pla = 0
    gartner_slo = 1
    gartner_tro = 0
elif gartner == 'Through':
    gartner_tri = 0
    gartner_peak = 0
    gartner_pla = 0
    gartner_slo = 0
    gartner_tro = 1   
else:
    print('Error in inputed variable.')

# %%
d1 = X.iloc[0:0]
d1

new_row = {'Employee Count':employee ,'Number of Investors in Seed':seed,'Number of Investors in Angel and or VC':vc, 'Number of Co-founders':co_founders,
       'Number of of advisors':advisors, 'Team size Senior leadership':senior,
       'Number of of repeat investors':repeat, 'Worked in top companies_No':top_comp_no,
       'Worked in top companies_Yes':top_comp_no,
       'Have been part of startups in the past?_No':past_su_no,
       'Have been part of startups in the past?_Yes':past_su_no,
       'Have been part of successful startups in the past?_No':past_ssu_no,
       'Have been part of successful startups in the past?_Yes':past_ssu_yes,
       'Was he or she partner in Big 5 consulting?_No':big5_no,
       'Was he or she partner in Big 5 consulting?_Yes':big5_yes,
       'Consulting experience?_No':consulting_no, 'Consulting experience?_Yes':consulting_yes,
       'Local or global player_global':where_global, 'Local or global player_local':where_local,
       'B2C or B2B venture?_B2B':market_B2B, 'B2C or B2B venture?_B2C':market_B2C,
       'Average Years of experience for founder and co founder_High':experience_high,
       'Average Years of experience for founder and co founder_Low':experience_low,
       'Average Years of experience for founder and co founder_Medium':experience_medium,
       'Breadth of experience across verticals_High':experience1_high,
       'Breadth of experience across verticals_Low':experience1_low,
       'Breadth of experience across verticals_Medium':experience1_medium,
       'Years of education_18':education_18, 'Years of education_21':education_21,
       'Years of education_25':education_25, 'Relevance of education to venture_No':ed_relevance_no,
       'Relevance of education to venture_Yes':ed_relevance_yes,
       'Relevance of experience to venture_No':ex_relevance_no,
       'Relevance of experience to venture_Yes':ex_relevance_yes,
       'Experience in selling and building products_High':selling_high,
       'Experience in selling and building products_Low':selling_low,
       'Experience in selling and building products_Medium':selling_medium,
       'Experience in selling and building products_None':selling_none,
       'Dificulty of Obtaining Work force_High':workforce_high,
       'Dificulty of Obtaining Work force_Low':workforce_low,
       'Dificulty of Obtaining Work force_Medium':workforce_medium, 'Pricing Strategy_No':pricing_no,
       'Pricing Strategy_Yes':pricing_yes, 'Time to market service or product_High':time_high,
       'Time to market service or product_Low':time_low,
       'Time to market service or product_Medium':time_medium,
       'Barriers of entry for the competitors_No':barriers_no,
       'Barriers of entry for the competitors_Yes':barriers_yes, 'Company awards_No':awards_no,
       'Company awards_Yes':awards_yes, 'Disruptiveness of technology_High':disruptive_high,
       'Disruptiveness of technology_Low':disruptive_low,
       'Disruptiveness of technology_Medium':disruptive_medium, 'Gartner hype cycle stage_Peak':gartner_peak,
       'Gartner hype cycle stage_Plateau':gartner_pla, 'Gartner hype cycle stage_Slope':gartner_slo,
       'Gartner hype cycle stage_Trigger':gartner_tri, 'Gartner hype cycle stage_Trough':gartner_tro}

d1 = d1.append(new_row, ignore_index=True)

d1

# %%
y_pred = logreg.predict(d1)
prediction = y_pred[0]
prediction

# %%
import os
import smtplib
from email.message import EmailMessage

EMAIL_ADDRESS = os.environ.get("EMAIL_ADDRESS")
EMAIL_PASSWORD = os.environ.get("EMAIL_PASSWORD")

msg = EmailMessage()
msg["Subject"] = "Startup Success Model"
msg["From"] = EMAIL_ADDRESS
msg["To"] = email_receiver

if prediction == 1:
    msg.set_content("Congratulations! According to our model, and given the inputed data, the startup will be successful. Check this link for an indepth graphical analysis of startups factors predictive of succes: https://public.tableau.com/profile/telma.batista#!/vizhome/Start-upProject/Dashboard1")
else:
    msg.set_content("We're sorry, but according to our model, and given the inputed data, the startup will not succeed. Check this link for an indepth graphical analysis of startups factors predictive of succes: https://public.tableau.com/profile/telma.batista#!/vizhome/Start-upProject/Dashboard1")

with smtplib.SMTP_SSL("smtp.gmail.com", 465) as smtp:
    smtp.login(EMAIL_ADDRESS,EMAIL_PASSWORD)
    smtp.send_message(msg)
